# %%
import pyarrow as pa
from pyarrow_schema import *
import pandas as pd

# %%
file_path = r"C:\Users\Hoang\OneDrive\Desktop\08_01_00.parquet"

df = pd.read_parquet(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3219 entries, 0 to 3218
# Data columns (total 53 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   event_type             3219 non-null   category
#  1   actor_login            3219 non-null   object
#  2   repo_name              3219 non-null   object
#  3   created_at             3219 non-null   datetime64[ms, UTC]
#  4   updated_at             421 non-null    datetime64[ms, UTC]
#  5   action                 594 non-null    category
#  6   comment_id             82 non-null     float64
#  7   body                   363 non-null    object
#  8   path                   19 non-null     object
#  9   position               19 non-null     float64
#  10  line                   19 non-null     float64
#  11  ref                    2491 non-null   object
#  12  ref_type               346 non-null    category
#  13  creator_user_login     421 non-null    object
# ...

# %%
df.head()
# Out:
#          event_type          actor_login                         repo_name  \
# 0         PushEvent  github-actions[bot]          nectariferous/TestFlight
# 1         PushEvent            calbrecht                 mayflower/nixpkgs
# 2  PullRequestEvent      jeffrey20050104  Yanagi-0912/weblesson_maindesign
# 3         PushEvent              Zairasg            Zairasg/pattern-design
# 4         PushEvent              coooolk   coooolk/Wanderlust-Mega-Project
#
#                  created_at                updated_at  action  comment_id  \
# 0 2024-12-01 08:00:00+00:00                       NaT     NaN         NaN
# 1 2024-12-01 08:00:00+00:00                       NaT     NaN         NaN
# 2 2024-12-01 08:00:00+00:00 2024-12-01 07:59:59+00:00  closed         NaN
# 3 2024-12-01 08:00:00+00:00                       NaT     NaN         NaN
# 4 2024-12-01 08:00:00+00:00                       NaT     NaN         NaN
#
# ...
